# %% [markdown]
# # Рабочая версия

# %%
import openpyxl
from datetime import date, datetime 

# Запись в дату текушую дату в формате 2020-11-08 
data = str(datetime.today())
today = data[:10]
# print(today)
# today = '-'.join(today)
today = today.split('-')
# print(today)
today = '{2},{1},{0}'.format(today[0][2:], today[1], today[2],)
print(today)
# Загружаем рабочий ексельфайл
wb = openpyxl.load_workbook(filename = 'Pricess2.xlsx')
# Загружаем рабочий лист
sheet_price1 = wb['Price1']
sheet_price2 = wb['Price2']
sheet_kurs = wb['Kurs']



# Полезно 
# sheet_kurs.max_row    -  максимум рядков, номер 
# sheet_kurs.min_row    -  максимум рядков, номер 
# sheet_kurs.max_column  максимум колонок, номер 
# sheet_kurs.min_column  максимум колонок, номер


#------Функция читает содержимое ячейки из листа "sheet_kurs" по существующим  рядкам--------------- 

def read_kurs(sheet=sheet_kurs):
    """Функция читает содержимое ячейки из листа "Kurs" по существующим  рядкам
    """
    # Итерируемся из списка мин до макс кол рядков  
    print('Start read kurs')
    for i in range(sheet_kurs.min_row, sheet_kurs.max_row + 1):
        # значение ячейки
        value = sheet.cell(i , 2).value
        value = str(value)
        print('read_kurs', value)
        # Если ячейка не пустая то заглянем туда
        if value != 'None' and value == today:
            print('read_kurs_2', value)
            # Вызываем впомогательную фукцию которая проитерируется по колонкам и найдет значения
            res = read_col_kurs(i)
#             print(res)
            return res
#-----------------------------------------------------------------------------------------------------

#------Вспомагательная функция читает содержимое ячейки из "sheet_kurs" по существующим  колонкам------           

def read_col_kurs(row, sheet=sheet_kurs):
    # Список со значениями, куда мы будем записывать курсы
    read = []
    """Функция читает содержимое ячейки из листа "sheet_kurs" по существующим  колонкам    
       row - ряд в таблице
       sheet=sheet_kurs - лист екселя в котором делается работа.
    """
    # Итерируемся по непустым колонкам
    for ii in range(sheet_kurs.min_column, sheet_kurs.max_column):
    
        # Читаем значения ячейки начиная со второй, ибо первая это сама дата
        value = sheet.cell(row, ii+1).value
        # Добавляем значение в наш список
        read.append(value)
        print('read_col_kurs', value)
    return read
#-----------------------------------------------------------------------------------------------------

#------Функция читает содержимое из листа "sheet_price2" и определяет єто evro или dolars------------- 

def read_val(sheet=sheet_price2):
    """Функция читает содержимое ячейки из листа "Price2" по существующим  рядкам
    """
    print(sheet_price2.min_column, sheet_price2.max_column + 1)
    # Итерируемся из списка мин до макс кол рядков  
    for i in range(sheet_price2.min_column, sheet_price2.max_column + 1):
        # значение ячейки
        value = sheet.cell(i , 11).value
        if value == 'dolar':
            price = sheet.cell(i , 10).value
            print(price*read_kurses[0])
            dolar(i, price)
            print('yes, dolar')
        elif value == 'evro':
            price = sheet.cell(i , 10).value
            evro(i, price)
            print('yes, evro')
            
#-----------------------------------------------------------------------------------------------------

def read_no_p1(sheet=sheet_price1):
    """
    """
    # Итерируемся из списка мин до макс кол рядков  
    for i in range(9, sheet.max_column + 1):
        # значение ячейки
        value = sheet.cell(i , 19).value
#         if value != 'None':
        print('read_no_p1-value', value)
#         no_value = sheet.cell(i , 16).value
#         print('read_no_p2-no_value', no_value)
        read_no_p2(value, i)
           
            
            
#-----------------------------------------------------------------------------------------------------

def read_no_p2(no, row, sheet=sheet_price1, sheet2=sheet_price2):
    """
    """
    # Итерируемся из списка мин до макс кол рядков  
    for i in range(sheet2.min_column, sheet2.max_column + 1):
        # значение ячейки
        no_valuee = sheet.cell(i , 16).value
        print('read_no_p2', no_valuee)
        valuee = sheet.cell(i , 10).value
        print('read_no_p2', valuee)
        if no_valuee == no:
            print('read_no_p1-no_value', no_valuee)
            price = sheet2.cell(row , 12).value
            print('read_no_p1', price)
            sheet.cell(i , 16).value = price
        

# def read_no_2(sheet=sheet_price2):
#     """
#     """
#     # Итерируемся из списка мин до макс кол рядков  
#     for i in range(sheet_price2.min_column, sheet_price2.max_column + 1):
#         # значение ячейки
#         value = sheet.cell(i , 10).value
#         print('read_no_p2-value', value)
#         no_value = sheet.cell(i , 16).value
#         print('read_no_p2-no_value', no_value)
#         read_no_p1(no_value, i)
           
            
            
# #-----------------------------------------------------------------------------------------------------

# def read_no_p1(no, row, sheet=sheet_price1, sheet2=sheet_price2):
#     """
#     """
#     # Итерируемся из списка мин до макс кол рядков  
#     for i in range(sheet_price2.min_column, sheet_price2.max_column + 1):
#         # значение ячейки
#         no_valuee = sheet.cell(i , 19).value
#         if no_valuee == no:
#             print('read_no_p1-no_value', no_valuee)
#             price = sheet2.cell(row , 12).value
#             print('read_no_p1', price)
#             sheet.cell(i , 16).value = price
            
#-----------------------------------------------------------------------------------------------------

def nds(val):
    val = (val/1.2)+0.005
    val =  round(val, 2)
    val = val*1.2
    res = float("%.3f" % (val))
    return res
    
#-----------------------------------------------------------------------------------------------------

#-----------------------------------------------------------------------------------------------------

#-----------------------------------------------------------------------------------------------------

def evro(row, price, column_pre=12, column_post=13, ws=sheet_price2):
    try:
        ws.cell(row , column_pre).value = price*read_kurses[2]
        ws.cell(row , column_post).value = price*read_kurses[3]
#         save('Pricess2.xlsx')
        return print(price,'ok')
    except Exception as e:
        print(e)    
        

#-----------------------------------------------------------------------------------------------------

def dolar(row, price, column_pre=12, column_post=13, ws=sheet_price2):

    try:
#         wbb = openpyxl.load_workbook(filename=path)
#         ws = wbb.worksheets[1]
#         value = 
        ws.cell(row , column_pre).value = price*read_kurses[0]
        ws.cell(row , column_post).value = price*read_kurses[1]
#         save('Pricess2.xlsx')
        return print(price,'ok')
    except Exception as e:
        print(e)    
#-----------------------------------------------------------------------------------------------------

def write_info(row , col, value, ws=sheet_price2):
    try:
        ws.cell(row , col).value = value
#         save('Pricess2.xlsx')
        print(ws.cell(row , col).value,'ok')
    except Exception as e:
        print(e)    
                
# def write(ryad , col, value):  
#         wb = openpyxl.load_workbook(filename='C:\\Users\\Sales2\Desktop\Pricess.xlsx' )
#         ws = wb.worksheets[0]
#         ws.cell(ryad , col).value = value
#         wb.save('C:\\Users\\Sales2\Desktop\Pricess.xlsx')
#         return print(ws.cell(ryad , col).value,'ok')
#-----------------------------------------------------------------------------------------------------
def save(name):
    try:
        wb.save(name)
        print("{0} is SAVE".format(name))
    except Exception as e:
        print(e)

#-----------------------------------------------------------------------------------------------------
def write_all_info():    
    try:
        write_info(21, 4, today)
        write_info(22, 6, read_kurses[0])
        write_info(22, 7, read_kurses[1])
        write_info(23, 6, read_kurses[2])
        write_info(23, 7, read_kurses[3])
    except Exception as e:
        print(e)
#-----------------------------------------------------------------------------------------------------    
    
 
read_kurses = read_kurs()
read_val()
write_all_info()
read_no_p1()
# save('Pricess2.xlsx')


































# Фукция делает запись.
# def write(ryad , col, value, sheet=sheet_price2):
#     """ ryad 
#         col
#         value
#         path= 'C:\\Users\\Sales2\\Desktop\\test\\Pricess2.xlsx'
#     """
#     try:
# #         wbb = openpyxl.load_workbook(filename=path)
# #         ws = wbb.worksheets[1]
#         ws.cell(ryad , col).value = value
#         wbb.save(path)
#         return print([ws.cell(ryad , col).value,'ok'])
#     except Exception as e:
#         print(e)
    
    
    
    
    
    
# for i in range(1, 50):
#     value = sheet_ranges['P{0}'.format(i)].value
#     if value and type(value) == int:
#         price_dict[value] = sheet_ranges['L{0}'.format(i)].value
#         #print(value, sheet_ranges['L{0}'.format(i)].value)

# print(price_dict.keys())   # dict_keys([1, 2, 3, 4, 5, 8, 7, 6, 19, 9, 10, 11, 12, 13, 14, 15, 18, 16, 17])
# print(price_dict)  #     {1: '77.62', 2: '86.06', 3: '84.67', 4: '143.44', 5: '81.00', 8: '88.97', 7: '91.84', 
#                    #    6: '0.00', 19: '0.00', 9: '87.75', 10: '131.62', 11: '135.00', 12: '143.44', 13: '152.11', 
#                    #  14: '243.95', 15: '132.02', 18: '0.00', 16: '48.79', 17: '0.00'}
                      
                   
    
# for i in range(8, 28):
#     value = sheet_ranges2['S{0}'.format(i)].value
#     if value != None:
#         print(value)
#         if int(value) in price_dict.keys():
#             print(i)
#             price = price_dict[value] 
#             write(i, 16, round(price, 1))
            
# write(31, 12, data)
        
#         try:
# #             write(i, 16, price_dict[i])
#             print(price_dict[i])
#         except Exception as e:

#             print(e)
# Out:
# 14,01,21
# Start read kurs
# read_kurs Дата:
# read_kurs 14,01,21
# read_kurs_2 14,01,21
# read_col_kurs 28.3
# read_col_kurs 28.7
# read_col_kurs 34.4
# read_col_kurs 34.8
# 1 25
# 2.3 ok
# yes, evro
# 2.6 ok
# yes, evro
# 89.145
# 3.15 ok
# yes, dolar
# 4.25 ok
# yes, evro
# 2.45 ok
# yes, evro
# 94.805
# 3.35 ok
# yes, dolar
# 96.22
# 3.4 ok
# yes, dolar
# 0.0
# 0 ok
# yes, dolar
# 0 ok
# yes, evro
# 2.7 ok
# yes, evro
# 3.9 ok
# yes, evro
# 4 ok
# yes, evro
# 4.25 ok
# yes, evro
# 149.99
# 5.3 ok
# yes, dolar
# 240.55
# 8.5 ok
# yes, dolar
# 127.35000000000001
# 4.5 ok
# yes, dolar
# 0.0
# 0 ok
# yes, dolar
# 72.16499999999999
# 2.55 ok
# yes, dolar
# 0.0
# 0 ok
# yes, dolar
# 14,01,21 ok
# 28.3 ok
# 28.7 ok
# 34.4 ok
# 34.8 ok
# read_no_p1-value 1
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 2
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 3
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 4
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 5
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 6
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 7
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 8
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 9
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 9
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 9
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 10
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 11
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 12
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 13
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p1-value 14
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 payment
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 None
# read_no_p2 Ціна:
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None
# read_no_p2
# read_no_p2 None

# %%
from xlrd import open_workbook
import datetime
import openpyxl
import xlwt

a = str(datetime.datetime.today())
date = a[8:10] + ',' + a[5:7] + ',' + a[2:4]
print(date)
book = open_workbook('C:\\Users\Sales2\Desktop\Александр&БАЗА\ВсеКлиентыДляБазыsales2\Остальное\КурсВалют.xls')
sheet = book.sheet_by_index(0)

def dolars():
    from xlrd import open_workbook    
    book = open_workbook('C:\\Users\Sales2\Desktop\Александр&БАЗА\ВсеКлиентыДляБазыsales2\Остальное\КурсВалют.xls')
    sheet = book.sheet_by_index(0)
    try:    
        for i in range(10000):
            if sheet.row_values(i)[5]:
                if sheet.row_values(i)[5] == date:
                    dolars = sheet.row_values(i)[6]
                    print(dolars)
            else:
                print('dich')
                break
    except Exception as e:
        print(e)
    return dolars
dolars = dolars()
 
def dolars_ots():
    from xlrd import open_workbook    
    book = open_workbook('C:\\Users\Sales2\Desktop\Александр&БАЗА\ВсеКлиентыДляБазыsales2\Остальное\КурсВалют.xls')
    sheet = book.sheet_by_index(0)
    try:    
        for i in range(10000):
            if sheet.row_values(i)[5]:
                if sheet.row_values(i)[5] == date:
                    dolars_ots = sheet.row_values(i)[7]
            else:
                break
    except Exception as e:
        print(e)
    return dolars_ots
dolars_ots = dolars_ots()




def evro():
    from xlrd import open_workbook    
    book = open_workbook('C:\\Users\Sales2\Desktop\Александр&БАЗА\ВсеКлиентыДляБазыsales2\Остальное\КурсВалют.xls')
    sheet = book.sheet_by_index(0)
    try:    
        for i in range(1000):
            if sheet.row_values(i)[5]:
                if sheet.row_values(i)[5] == date:
                    evro = sheet.row_values(i)[8]
            else:
                break
    except Exception as e:
#         print(e)
        pass
    return evro
evro = evro()
 
def evro_ots():
    from xlrd import open_workbook    
    book = open_workbook('C:\\Users\Sales2\Desktop\Александр&БАЗА\ВсеКлиентыДляБазыsales2\Остальное\КурсВалют.xls')
    sheet = book.sheet_by_index(0)
    try:    
        for i in range(1000):
            if sheet.row_values(i)[5]:
                if sheet.row_values(i)[5] == date:
                    evro_ots = sheet.row_values(i)[9]
            else:
                break
    except:
        pass
    return evro_ots
evro_ots = evro_ots()

book2 = open_workbook('C:\\Users\Sales2\Desktop\Pricess.xlsx')
sheet2 = book2.sheet_by_index(0)

try:
    def write(ryad , col, value):  
        wb = openpyxl.load_workbook(filename='C:\\Users\\Sales2\Desktop\Pricess.xlsx' )
        ws = wb.worksheets[0]
        ws.cell(ryad , col).value = value
        wb.save('C:\\Users\\Sales2\Desktop\Pricess.xlsx')
        return print(ws.cell(ryad , col).value,'ok')
except Exception as e:
    print(e)


try:
    write(21, 4, date)
    write(22, 6, dolars)
    write(22, 7, dolars_ots)
    write(23, 6, evro)
    write(23, 7, evro_ots)
    for i in range(10000):
        if sheet2.row_values(i)[10]:
#             print(sheet2.row_values(i)[10])
            if sheet2.row_values(i)[10] == 'evro':
#                 print(evro)
                evros = sheet2.row_values(i)[9] * evro
                evros_opt = sheet2.row_values(i)[8] * evro
#                 print(evros)
                evros = '{:.2f}'.format(evros)
                evros_opt = '{:.2f}'.format(evros_opt)                
                evros_ots = sheet2.row_values(i)[9] * evro_ots
                evros_ots_opt = sheet2.row_values(i)[8] * evro_ots
                evros_ots= '{:.2f}'.format(evros_ots) 
                evros_ots_opt= '{:.2f}'.format(evros_ots_opt)
                write(i+1, 12, evros)
                write(i+1, 13, evros_ots)
                write(i+1, 14, evros_opt)
                write(i+1, 15, evros_ots_opt)
#                 evros_ots = sheet.row_values(i)[9] * evro_ots
#                 print(evros, evros_ots)
                
            elif sheet2.row_values(i)[10] == 'dolar':
                dolarse = sheet2.row_values(i)[9] * dolars
                dolarse_opt = sheet2.row_values(i)[8] * dolars
                dolarse = '{:.2f}'.format(dolarse)
                dolarse_opt = '{:.2f}'.format(dolarse_opt)
                dolarse_ots = sheet2.row_values(i)[9] * dolars_ots
                dolarse_ots_opt = sheet2.row_values(i)[8] * dolars_ots
                dolarse_ots = '{:.2f}'.format(dolarse_ots)
                dolarse_ots_opt = '{:.2f}'.format(dolarse_ots_opt)
#                 print(dolarse, dolarse_ots)
                write(i+1, 12, dolarse)
                write(i+1, 13, dolarse_ots)
                write(i+1, 14, dolarse_opt)
                write(i+1, 15, dolarse_ots_opt)        
except Exception as e:
    print(e,'?')
