# %% [markdown]
# # Рабочая версия

# %%
from googletrans import Translator
translator = Translator()
 



b = translator.translate('   20640000  PLUM FROZEN HALVES', dest='ru', src='en')
b.text
# Out:
# '20640000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ СЛИВЫ'

# %% [markdown]
# # Тесты

# %%
from datetime import datetime as dt
from datetime import date


translator = Translator()
da = str(dt.today())
print(da[:11])


dates = date.today()
dates.strftime("%d.%m.%y")
# Out:
# 2020-11-20
# '20.11.20'

# %%
import openpyxl
from datetime import date, datetime 
from googletrans import Translator


# Запись в дату текушую дату в формате 2020-11-08 
data = str(datetime.today())
print(data[:11])
# Загружаем рабочий ексельфайл
wb = openpyxl.load_workbook(filename = 'frozen.xlsx')
# Загружаем рабочий лист
sheet = wb['Sheet1']
sheet_2 = wb.worksheets[1]



def trans(text):
    b = translator.translate(text, dest='ru', src='en')
    return b.text


def write(ryad , col, value, ws=sheet_2):
    try:
        ws.cell(ryad , col).value = value
        wb.save('frozen.xlsx')
        return print([ws.cell(ryad , col).value,'ok'])
    except Exception as e:
        print(e)



#------Функция читает содержимое ячейки из листа "sheet_kurs" по существующим  рядкам--------------- 
base = {}

def read_kurs(sheet=sheet, base=base):
    name = ''
    datt = ''
    inc = ''
    # Итерируемся из списка мин до макс кол рядков  
    for i in range(sheet.min_row, sheet.max_row + 1):
        # значение ячейки
        value = sheet.cell(i , 1).value
        value_2 = str(sheet.cell(i , 2).value)
        value = str(value)
        if value != 'None':
            if value_2 not in base.keys():
                base[value_2] = []
                name = value_2
                datt = sheet.cell(i , 1).value
                inc = sheet.cell(i , 3).value
            else:
                name = value_2
                datt = sheet.cell(i , 1).value
                inc = sheet.cell(i , 3).value
            print('name is {0}'.format(name))
        else:
            try:
                print(base[name])
                a = base[name]
                a.append(value_2)
                write(i, 2, name)  #  Постачальник
                write(i, 3, value_2 + trans(value_2)) # Product /  Продукт
                write(i, 1, datt) # Дата
                write(i, 4, inc) # 
                write(i, 5, sheet.cell(i , 4).value) #
                write(i, 6, sheet.cell(i , 5).value) #
                write(i, 7, sheet.cell(i , 6).value) #
                write(i, 8, sheet.cell(i , 7).value) #
                write(i, 9, sheet.cell(i , 8).value) #
            except Exception as e:
                print(e)
#         print(value)
# Out:
# 2020-11-20

# %%
read_kurs()
# Out:
# name is Address / product/ Постачальник та продукт
# name is Parfeniuk V. V.
# []
# ['Parfeniuk V. V.', 'ok']
# ['   20020038  BLUEBERRY FROZEN20020038 ЧЕРНИКА ЗАМОРОЖЕННАЯ', 'ok']
# ['16.11.2020', 'ok']
# ['DDP', 'ok']
# [' 16.10.2020', 'ok']
# ['paperbag', 'ok']
# [10000, 'ok']
# [81.34, 'ok']
# ['813.400,00  UAH', 'ok']
# name is Berry Mor LLC
# []
# ['Berry Mor LLC ', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE20050000 ИСТОЧНИКИ ЗАМОРОЖЕННЫЕ КЛАСС 1, БЕЗ КАМНЯ', 'ok']
# ['10.11.2020', 'ok']
# ['EXW', 'ok']
# [' 10.11.2020', 'ok']
# ['carton', 'ok']
# [5040, 'ok']
# [34.95, 'ok']
# ['176.148,00  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE']
# ['Berry Mor LLC ', 'ok']
# ['   20640000  PLUM FROZEN HALVES20640000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ СЛИВЫ', 'ok']
# ['06.11.2020', 'ok']
# ['DDP', 'ok']
# [' 06.11.2020', 'ok']
# ['carton', 'ok']
# [500, 'ok']
# [21.45, 'ok']
# ['10.725,00  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES']
# ['Berry Mor LLC ', 'ok']
# ['   20640000  PLUM FROZEN HALVES20640000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ СЛИВЫ', 'ok']
# ['30.10.2020', 'ok']
# ['DDP', 'ok']
# [' 30.10.2020', 'ok']
# ['carton', 'ok']
# [100, 'ok']
# [25.74, 'ok']
# ['2.574,00  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES']
# ['Berry Mor LLC ', 'ok']
# ['   20630001  SPINACH FROZEN CUT20630001 ШПИНАТ ЗАМОРОЖЕННЫЙ', 'ok']
# ['23.10.2020', 'ok']
# ['DDP', 'ok']
# [' 23.10.2020', 'ok']
# ['carton', 'ok']
# [50, 'ok']
# [22.3, 'ok']
# ['1.115,00  UAH', 'ok']
# name is Nagaychuk D V FOP
# []
# ['Nagaychuk D V FOP', 'ok']
# ['   20320000  APRICOT FROZEN HALVES20320000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ АБРИКОСА', 'ok']
# ['20.10.2020', 'ok']
# ['DDP', 'ok']
# [' 20.10.2020', 'ok']
# ['carton', 'ok']
# [1500, 'ok']
# [40.22, 'ok']
# ['60.330,00  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT']
# ['Berry Mor LLC ', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE20050000 ИСТОЧНИКИ ЗАМОРОЖЕННЫЕ КЛАСС 1, БЕЗ КАМНЯ', 'ok']
# ['19.10.2020', 'ok']
# ['DDP', 'ok']
# [' 19.10.2020', 'ok']
# ['carton', 'ok']
# [5000, 'ok']
# [34.75, 'ok']
# ['173.750,00  UAH', 'ok']
# name is Krasberi-Ukraina LLC
# []
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM20240007 АНАНАС ЗАМОРОЖЕННЫЙ КУБИК 20Х20 ММ', 'ok']
# ['19.10.2020', 'ok']
# ['DDP', 'ok']
# [' 19.10.2020', 'ok']
# ['carton', 'ok']
# [2080, 'ok']
# [58.33, 'ok']
# ['121.326,40  UAH', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20200006  MANGO FROZEN CUBE 20 X 20 MM20200006 ЗАМОРОЖЕННЫЙ КУБ МАНГО 20 Х 20 ММ', 'ok']
# ['19.10.2020', 'ok']
# ['DDP', 'ok']
# [' 19.10.2020', 'ok']
# ['carton', 'ok']
# [1520, 'ok']
# [72.08, 'ok']
# ['109.561,60  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE']
# ['Berry Mor LLC ', 'ok']
# ['   20470000  PEAR FROZEN CUBE20470000 ГРУША ЗАМОРОЖЕННЫЙ КУБ', 'ok']
# ['16.10.2020', 'ok']
# ['DDP', 'ok']
# [' 16.10.2020', 'ok']
# ['carton', 'ok']
# [490, 'ok']
# [23.95, 'ok']
# ['11.735,50  UAH', 'ok']
# name is Hordiichuk A. V.
# []
# ['Hordiichuk A. V.', 'ok']
# ['   20020038  BLUEBERRY FROZEN20020038 ЧЕРНИКА ЗАМОРОЖЕННАЯ', 'ok']
# ['16.10.2020', 'ok']
# ['DDP', 'ok']
# [' 16.10.2020', 'ok']
# ['paperbag', 'ok']
# [10000, 'ok']
# [81.34, 'ok']
# ['813.400,00  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20470000  PEAR FROZEN CUBE']
# ['Berry Mor LLC ', 'ok']
# ['   20640000  PLUM FROZEN HALVES20640000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ СЛИВЫ', 'ok']
# ['13.10.2020', 'ok']
# ['DDP', 'ok']
# [' 13.10.2020', 'ok']
# ['carton', 'ok']
# [50, 'ok']
# [21.45, 'ok']
# ['1.072,50  UAH', 'ok']
# name is Danon Dnipro, LLC
# []
# ['Danon Dnipro, LLC', 'ok']
# ['   70010012  STRAWBERRY FROZEN CLASS 1 CUBE 10X10 MM70010012 КУБИК КЛУБНИЧНЫЙ ЗАМОРОЖЕННЫЙ КЛАСС 1 10X10 ММ', 'ok']
# ['12.10.2020', 'ok']
# ['FCA', 'ok']
# [' 12.10.2020', 'ok']
# ['carton 15 kg', 'ok']
# [1200, 'ok']
# [47.32, 'ok']
# ['56.784,00  UAH', 'ok']
# name is Zemlia Organic LLC
# []
# ['Zemlia Organic LLC', 'ok']
# ['   20010118  STRAWBERRY FROZEN ORGANIC20010118 КЛУБНИКА ЗАМОРОЖЕННАЯ ОРГАНИЧЕСКАЯ', 'ok']
# ['08.10.2020', 'ok']
# ['DDP', 'ok']
# [' 08.10.2020', 'ok']
# ['paperbag', 'ok']
# [10764, 'ok']
# [78.325, 'ok']
# ['843.090,30  UAH', 'ok']
# name is Zemlia Organic LLC
# ['   20010118  STRAWBERRY FROZEN ORGANIC']
# ['Zemlia Organic LLC', 'ok']
# ['   20010118  STRAWBERRY FROZEN ORGANIC20010118 КЛУБНИКА ЗАМОРОЖЕННАЯ ОРГАНИЧЕСКАЯ', 'ok']
# ['08.10.2020', 'ok']
# ['DDP', 'ok']
# [' 08.10.2020', 'ok']
# ['palbox', 'ok']
# [5000, 'ok']
# [77.317, 'ok']
# ['386.585,00  UAH', 'ok']
# name is Semko LLC
# []
# ['Semko LLC', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE20050000 ИСТОЧНИКИ ЗАМОРОЖЕННЫЕ КЛАСС 1, БЕЗ КАМНЯ', 'ok']
# ['06.10.2020', 'ok']
# ['DDP', 'ok']
# [' 06.10.2020', 'ok']
# ['carton', 'ok']
# [5000, 'ok']
# [33.33, 'ok']
# ['1.666,67  UAH', 'ok']
# name is Zaxarchuk V.V. FOP
# []
# ['Zaxarchuk V.V. FOP', 'ok']
# ['   20060014  CHOKEBERRY FROZEN20060014 КОКБЕРНИ ЗАМОРОЖЕННЫЙ', 'ok']
# ['05.10.2020', 'ok']
# ['DDP', 'ok']
# [' 05.10.2020', 'ok']
# ['box wood', 'ok']
# [3150, 'ok']
# [20, 'ok']
# ['63.000,00  UAH', 'ok']
# name is Yarofrut LLC
# []
# ['Yarofrut LLC', 'ok']
# ['   20250003  CARROT FROZEN CUBE 10X10 MM20250003 МОРКОВНЫЙ ЗАМОРОЖЕННЫЙ КУБИК 10X10 ММ', 'ok']
# ['01.10.2020', 'ok']
# ['DDP', 'ok']
# [' 01.10.2020', 'ok']
# ['paperbag', 'ok']
# [100, 'ok']
# [13.33, 'ok']
# ['1.333,00  UAH', 'ok']
# name is Buzuluk R.S. FOP
# []
# ['Buzuluk R.S. FOP', 'ok']
# ['   20060014  CHOKEBERRY FROZEN20060014 КОКБЕРНИ ЗАМОРОЖЕННЫЙ', 'ok']
# ['01.10.2020', 'ok']
# ['DDP', 'ok']
# [' 01.10.2020', 'ok']
# ['box wood', 'ok']
# [5000, 'ok']
# [20, 'ok']
# ['100.000,00  UAH', 'ok']
# name is Koval'chuk A.A.
# []
# ["Koval'chuk A.A.", 'ok']
# ['   20730007  BOG BLUEBERRY FROZEN20730007 БОГ ЧЕРНИКА ЗАМОРОЖЕННАЯ', 'ok']
# ['01.10.2020', 'ok']
# ['DDP', 'ok']
# [' 01.10.2020', 'ok']
# ['plast.box_sm', 'ok']
# [15475, 'ok']
# [73.32, 'ok']
# ['1.134.627,00  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20470000  PEAR FROZEN CUBE', '   20640000  PLUM FROZEN HALVES']
# ['Berry Mor LLC ', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE20050000 ИСТОЧНИКИ ЗАМОРОЖЕННЫЕ КЛАСС 1, БЕЗ КАМНЯ', 'ok']
# ['29.09.2020', 'ok']
# ['DDP', 'ok']
# [' 23.09.2020', 'ok']
# ['carton', 'ok']
# [2450, 'ok']
# [35.6, 'ok']
# ['87.220,00  UAH', 'ok']
# name is Krasberi-Ukraina LLC
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM20240007 АНАНАС ЗАМОРОЖЕННЫЙ КУБИК 20Х20 ММ', 'ok']
# ['16.09.2020', 'ok']
# ['DDP', 'ok']
# [' 16.09.2020', 'ok']
# ['carton', 'ok']
# [1260, 'ok']
# [56.67, 'ok']
# ['71.404,20  UAH', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20200006  MANGO FROZEN CUBE 20 X 20 MM20200006 ЗАМОРОЖЕННЫЙ КУБ МАНГО 20 Х 20 ММ', 'ok']
# ['16.09.2020', 'ok']
# ['DDP', 'ok']
# [' 16.09.2020', 'ok']
# ['carton', 'ok']
# [1280, 'ok']
# [70.83, 'ok']
# ['90.662,40  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20470000  PEAR FROZEN CUBE', '   20640000  PLUM FROZEN HALVES', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE']
# ['Berry Mor LLC ', 'ok']
# ['   20010018  STRAWBERRY FROZEN20010018 КЛУБНИКА ЗАМОРОЖЕННАЯ', 'ok']
# ['16.09.2020', 'ok']
# ['DDP', 'ok']
# [' 16.09.2020', 'ok']
# ['paperbag', 'ok']
# [25, 'ok']
# [43.6, 'ok']
# ['1.090,00  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20470000  PEAR FROZEN CUBE', '   20640000  PLUM FROZEN HALVES', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20010018  STRAWBERRY FROZEN']
# ['Berry Mor LLC ', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE20050000 ИСТОЧНИКИ ЗАМОРОЖЕННЫЕ КЛАСС 1, БЕЗ КАМНЯ', 'ok']
# ['14.09.2020', 'ok']
# ['DDP', 'ok']
# [' 15.09.2020', 'ok']
# ['carton', 'ok']
# [1500, 'ok']
# [42.72, 'ok']
# ['64.080,00  UAH', 'ok']
# name is Setton, LLC
# []
# ['Setton, LLC', 'ok']
# ['   20070011  LINGONBERRY FROZEN20070011 БАКОВИНА ЗАМОРОЖЕННАЯ', 'ok']
# ['08.09.2020', 'ok']
# ['DAP', 'ok']
# [' 08.09.2020', 'ok']
# ['octabin', 'ok']
# [20000, 'ok']
# [2, 'ok']
# ['40.000,00  EUR', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE']
# ['Semko LLC', 'ok']
# ['   20200003  MANGO FROZEN CUT BITS20200003 ЗАМОРОЖЕННЫЕ БИТЫ ИЗ МАНГО', 'ok']
# ['08.09.2020', 'ok']
# ['DDP', 'ok']
# [' 08.09.2020', 'ok']
# ['carton', 'ok']
# [700, 'ok']
# [63.7833, 'ok']
# ['44.648,33  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20470000  PEAR FROZEN CUBE', '   20640000  PLUM FROZEN HALVES', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20010018  STRAWBERRY FROZEN', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE']
# ['Berry Mor LLC ', 'ok']
# ['   20620000  GREEN PEAS FROZEN20620000 ЗЕЛЕНЫЙ ГОРОХ ЗАМОРОЖЕННЫЙ', 'ok']
# ['01.09.2020', 'ok']
# ['DDP', 'ok']
# [' 01.09.2020', 'ok']
# ['paperbag', 'ok']
# [50, 'ok']
# [30.2, 'ok']
# ['1.510,00  UAH', 'ok']
# name is Berry Mor LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20470000  PEAR FROZEN CUBE', '   20640000  PLUM FROZEN HALVES', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20010018  STRAWBERRY FROZEN', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20620000  GREEN PEAS FROZEN']
# ['Berry Mor LLC ', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE20050000 ИСТОЧНИКИ ЗАМОРОЖЕННЫЕ КЛАСС 1, БЕЗ КАМНЯ', 'ok']
# ['31.08.2020', 'ok']
# ['DDP', 'ok']
# [' 31.08.2020', 'ok']
# ['carton', 'ok']
# [1000, 'ok']
# [34.1667, 'ok']
# ['34.166,70  UAH', 'ok']
# name is Kebaluk O R FOP
# []
# ['Kebaluk O R FOP', 'ok']
# ['   20030037  RASPBERRY FROZEN20030037 МАЛИНА ЗАМОРОЖЕННАЯ', 'ok']
# ['18.08.2020', 'ok']
# ['DDP', 'ok']
# [' 12.08.2020', 'ok']
# ['plast.box_sm', 'ok']
# [5408.5, 'ok']
# [53.5, 'ok']
# ['289.354,75  UAH', 'ok']
# name is Krasberi-Ukraina LLC
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM20240007 АНАНАС ЗАМОРОЖЕННЫЙ КУБИК 20Х20 ММ', 'ok']
# ['14.08.2020', 'ok']
# ['DDP', 'ok']
# [' 10.08.2020', 'ok']
# ['carton', 'ok']
# [440, 'ok']
# [59.17, 'ok']
# ['26.034,80  UAH', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20200006  MANGO FROZEN CUBE 20 X 20 MM20200006 ЗАМОРОЖЕННЫЙ КУБ МАНГО 20 Х 20 ММ', 'ok']
# ['14.08.2020', 'ok']
# ['DDP', 'ok']
# [' 10.08.2020', 'ok']
# ['carton', 'ok']
# [210, 'ok']
# [69.17, 'ok']
# ['14.525,70  UAH', 'ok']
# name is Larus LLC
# []
# ['Larus LLC', 'ok']
# ['   20020036  BLUEBERRY FROZEN B20020036 ЧЕРНИКА ЗАМОРОЖЕННАЯ B', 'ok']
# ['14.08.2020', 'ok']
# ['DDP', 'ok']
# [' 14.08.2020', 'ok']
# ['octabin', 'ok']
# [20068, 'ok']
# [79.285, 'ok']
# ['1.591.091,38  UAH', 'ok']
# name is Larus LLC
# ['   20020036  BLUEBERRY FROZEN B']
# ['Larus LLC', 'ok']
# ['   20020036  BLUEBERRY FROZEN B20020036 ЧЕРНИКА ЗАМОРОЖЕННАЯ B', 'ok']
# ['14.08.2020', 'ok']
# ['DDP', 'ok']
# [' 14.08.2020', 'ok']
# ['octabin', 'ok']
# [20060, 'ok']
# [79.31, 'ok']
# ['1.590.958,60  UAH', 'ok']
# name is Larus LLC
# ['   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B']
# ['Larus LLC', 'ok']
# ['   20020036  BLUEBERRY FROZEN B20020036 ЧЕРНИКА ЗАМОРОЖЕННАЯ B', 'ok']
# ['11.08.2020', 'ok']
# ['DDP', 'ok']
# [' 11.08.2020', 'ok']
# ['octabin', 'ok']
# [20000, 'ok']
# [75, 'ok']
# ['1.500.000,00  UAH', 'ok']
# name is Hayberry LLC
# []
# ['Hayberry LLC', 'ok']
# ['   20010018  STRAWBERRY FROZEN20010018 КЛУБНИКА ЗАМОРОЖЕННАЯ', 'ok']
# ['07.08.2020', 'ok']
# ['DDP', 'ok']
# [' 06.08.2020', 'ok']
# ['paperbag', 'ok']
# [20000, 'ok']
# [39.85, 'ok']
# ['797.000,00  UAH', 'ok']
# name is Larus LLC
# ['   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B']
# ['Larus LLC', 'ok']
# ['   20020036  BLUEBERRY FROZEN B20020036 ЧЕРНИКА ЗАМОРОЖЕННАЯ B', 'ok']
# ['06.08.2020', 'ok']
# ['DDP', 'ok']
# [' 06.08.2020', 'ok']
# ['octabin', 'ok']
# [19872, 'ok']
# [75, 'ok']
# ['1.490.400,00  UAH', 'ok']
# name is Larus LLC
# ['   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B']
# ['Larus LLC', 'ok']
# ['   20020036  BLUEBERRY FROZEN B20020036 ЧЕРНИКА ЗАМОРОЖЕННАЯ B', 'ok']
# ['05.08.2020', 'ok']
# ['DDP', 'ok']
# [' 05.08.2020', 'ok']
# ['paperbag', 'ok']
# [20000, 'ok']
# [75, 'ok']
# ['1.500.000,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS']
# ['Semko LLC', 'ok']
# ['   20200003  MANGO FROZEN CUT BITS20200003 ЗАМОРОЖЕННЫЕ БИТЫ ИЗ МАНГО', 'ok']
# ['04.08.2020', 'ok']
# ['DDP', 'ok']
# [' 04.08.2020', 'ok']
# ['cart. strong', 'ok']
# [20, 'ok']
# [62.95, 'ok']
# ['1.259,00  UAH', 'ok']
# name is TERCET-WEST, JLLC
# []
# ['TERCET-WEST, JLLC', 'ok']
# ['   20020036  BLUEBERRY FROZEN B20020036 ЧЕРНИКА ЗАМОРОЖЕННАЯ B', 'ok']
# ['31.07.2020', 'ok']
# ['DAP', 'ok']
# [' 01.08.2020', 'ok']
# ['octabin', 'ok']
# [20000, 'ok']
# [2.27, 'ok']
# ['45.400,00  EUR', 'ok']
# name is People
# []
# ['People', 'ok']
# ['   20290003  PEACH FROZEN HALFS20290003 ПЕРСИК ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ', 'ok']
# ['31.07.2020', 'ok']
# ['DDU', 'ok']
# [' 31.07.2020', 'ok']
# ['plast.box_sm', 'ok']
# [387, 'ok']
# [43.48, 'ok']
# ['16.826,76  UAH', 'ok']
# ['   20290003  PEACH FROZEN HALFS']
# ['People', 'ok']
# ['   20290003  PEACH FROZEN HALFS20290003 ПЕРСИК ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ', 'ok']
# ['31.07.2020', 'ok']
# ['DDU', 'ok']
# [' 31.07.2020', 'ok']
# ['plast.box_sm', 'ok']
# [63, 'ok']
# [45.65, 'ok']
# ['2.875,95  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS']
# ['Semko LLC', 'ok']
# ['   20200003  MANGO FROZEN CUT BITS20200003 ЗАМОРОЖЕННЫЕ БИТЫ ИЗ МАНГО', 'ok']
# ['31.07.2020', 'ok']
# ['DDP', 'ok']
# [' 31.07.2020', 'ok']
# ['cart. strong', 'ok']
# [600, 'ok']
# [62.95, 'ok']
# ['37.770,00  UAH', 'ok']
# name is Kuts A.V. FOP
# []
# ['Kuts A.V. FOP', 'ok']
# ['   70320004  APRICOT FROZEN HALFS70320004 АБРИКОС ЗАМОРОЖЕННЫЕ ПОЛОВИНКИ', 'ok']
# ['29.07.2020', 'ok']
# ['DDP', 'ok']
# [' 29.07.2020', 'ok']
# ['carton 10x1', 'ok']
# [3360, 'ok']
# [32.61, 'ok']
# ['109.569,60  UAH', 'ok']
# name is Larus LLC
# ['   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B']
# ['Larus LLC', 'ok']
# ['   20020036  BLUEBERRY FROZEN B20020036 ЧЕРНИКА ЗАМОРОЖЕННАЯ B', 'ok']
# ['20.07.2020', 'ok']
# ['DDP', 'ok']
# [' 20.07.2020', 'ok']
# ['PE-bag 25kg', 'ok']
# [20000, 'ok']
# [77.33, 'ok']
# ['1.546.600,00  UAH', 'ok']
# name is Larus LLC
# ['   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B']
# ['Larus LLC', 'ok']
# ['   20020036  BLUEBERRY FROZEN B20020036 ЧЕРНИКА ЗАМОРОЖЕННАЯ B', 'ok']
# ['17.07.2020', 'ok']
# ['DDP', 'ok']
# [' 17.07.2020', 'ok']
# ['PE-bag 25kg', 'ok']
# [20000, 'ok']
# [74.88, 'ok']
# ['1.497.600,00  UAH', 'ok']
# name is Berry-Trade, LLC
# []
# ['Berry-Trade, LLC', 'ok']
# ['   20010018  STRAWBERRY FROZEN20010018 КЛУБНИКА ЗАМОРОЖЕННАЯ', 'ok']
# ['17.07.2020', 'ok']
# ['DDU', 'ok']
# [' 17.07.2020', 'ok']
# ['plast.box_sm', 'ok']
# [13043, 'ok']
# [40, 'ok']
# ['521.720,00  EUR', 'ok']
# name is People
# ['   20290003  PEACH FROZEN HALFS', '   20290003  PEACH FROZEN HALFS']
# ['People', 'ok']
# ['   20630001  SPINACH FROZEN CUT20630001 ШПИНАТ ЗАМОРОЖЕННЫЙ', 'ok']
# ['16.07.2020', 'ok']
# ['DDP', 'ok']
# [' 16.07.2020', 'ok']
# ['carton', 'ok']
# [60, 'ok']
# [20, 'ok']
# ['1.200,00  UAH', 'ok']
# name is Krasberi-Ukraina LLC
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM20240007 АНАНАС ЗАМОРОЖЕННЫЙ КУБИК 20Х20 ММ', 'ok']
# ['10.07.2020', 'ok']
# ['DDP', 'ok']
# [' 01.07.2020', 'ok']
# ['plast.box_sm', 'ok']
# [1000, 'ok']
# [53.33, 'ok']
# ['53.330,00  UAH', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20200006  MANGO FROZEN CUBE 20 X 20 MM20200006 ЗАМОРОЖЕННЫЙ КУБ МАНГО 20 Х 20 ММ', 'ok']
# ['10.07.2020', 'ok']
# ['DDP', 'ok']
# [' 01.07.2020', 'ok']
# ['carton', 'ok']
# [1000, 'ok']
# [62.5, 'ok']
# ['62.500,00  UAH', 'ok']
# name is Cetera, LLC
# []
# ['Cetera, LLC', 'ok']
# ['   20250003  CARROT FROZEN CUBE 10X10 MM20250003 МОРКОВНЫЙ ЗАМОРОЖЕННЫЙ КУБИК 10X10 ММ', 'ok']
# ['07.07.2020', 'ok']
# ['DDU', 'ok']
# [' 07.07.2020', 'ok']
# ['carton', 'ok']
# [10, 'ok']
# [19.17, 'ok']
# ['191,70  UAH', 'ok']
# ['   20250003  CARROT FROZEN CUBE 10X10 MM']
# ['Cetera, LLC', 'ok']
# ['   70670002  CORN FROZEN CRUMBS70670002 КУКУРУЗА ЗАМОРОЖЕННАЯ КЫЧКА', 'ok']
# ['07.07.2020', 'ok']
# ['DDU', 'ok']
# [' 07.07.2020', 'ok']
# ['PE-bag 25kg', 'ok']
# [100, 'ok']
# [30.42, 'ok']
# ['3.042,00  UAH', 'ok']
# name is Tkach Y M O FOP
# []
# ['Tkach Y M O FOP', 'ok']
# ['   20320000  APRICOT FROZEN HALVES20320000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ АБРИКОСА', 'ok']
# ['26.06.2020', 'ok']
# ['DAP', 'ok']
# [' 26.06.2020', 'ok']
# ['carton', 'ok']
# [800, 'ok']
# [32.61, 'ok']
# ['26.088,00  UAH', 'ok']
# name is Tkach Y M O FOP
# ['   20320000  APRICOT FROZEN HALVES']
# ['Tkach Y M O FOP', 'ok']
# ['   20090002  SEA BUCKTHORN FROZEN CLASS 220090002 Облепиха замороженная, класс 2', 'ok']
# ['26.06.2020', 'ok']
# ['DAP', 'ok']
# [' 26.06.2020', 'ok']
# ['carton', 'ok']
# [200, 'ok']
# [54.35, 'ok']
# ['10.870,00  UAH', 'ok']
# name is DVIPA LLC
# []
# ['DVIPA LLC', 'ok']
# ['   20010118  STRAWBERRY FROZEN ORGANIC20010118 КЛУБНИКА ЗАМОРОЖЕННАЯ ОРГАНИЧЕСКАЯ', 'ok']
# ['18.06.2020', 'ok']
# ['EXW', 'ok']
# [' 18.06.2020', 'ok']
# ['carton', 'ok']
# [17818, 'ok']
# [54.17, 'ok']
# ['965.201,06  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS']
# ['Semko LLC', 'ok']
# ['   20670000  CORN FROZEN CRUMBS20670000 КУКУРУЗНЫЕ ЗАМОРОЖЕННЫЕ КЫШКИ', 'ok']
# ['15.06.2020', 'ok']
# ['DDU', 'ok']
# [' 15.06.2020', 'ok']
# ['carton', 'ok']
# [20, 'ok']
# [28.1, 'ok']
# ['562,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS']
# ['Semko LLC', 'ok']
# ['   20630001  SPINACH FROZEN CUT20630001 ШПИНАТ ЗАМОРОЖЕННЫЙ', 'ok']
# ['27.05.2020', 'ok']
# ['DDU', 'ok']
# [' 27.05.2020', 'ok']
# ['carton', 'ok']
# [70, 'ok']
# [23.1, 'ok']
# ['1.617,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT']
# ['Semko LLC', 'ok']
# ['   20320000  APRICOT FROZEN HALVES20320000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ АБРИКОСА', 'ok']
# ['07.05.2020', 'ok']
# ['DDU', 'ok']
# [' 07.05.2020', 'ok']
# ['carton', 'ok']
# [30, 'ok']
# [29.25, 'ok']
# ['877,50  UAH', 'ok']
# name is Krasberi-Ukraina LLC
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM20240007 АНАНАС ЗАМОРОЖЕННЫЙ КУБИК 20Х20 ММ', 'ok']
# ['01.05.2020', 'ok']
# ['EXW', 'ok']
# [' 01.05.2020', 'ok']
# ['carton', 'ok']
# [10, 'ok']
# [55, 'ok']
# ['550,00  UAH', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20200006  MANGO FROZEN CUBE 20 X 20 MM20200006 ЗАМОРОЖЕННЫЙ КУБ МАНГО 20 Х 20 ММ', 'ok']
# ['01.05.2020', 'ok']
# ['EXW', 'ok']
# [' 01.05.2020', 'ok']
# ['carton', 'ok']
# [10, 'ok']
# [68.3333, 'ok']
# ['683,33  UAH', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM']
# ['Krasberi-Ukraina LLC', 'ok']
# ['   20200006  MANGO FROZEN CUBE 20 X 20 MM20200006 ЗАМОРОЖЕННЫЙ КУБ МАНГО 20 Х 20 ММ', 'ok']
# ['01.05.2020', 'ok']
# ['EXW', 'ok']
# [' 01.05.2020', 'ok']
# ['PE-bag', 'ok']
# [2.5, 'ok']
# [68.3333, 'ok']
# ['170,83  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES']
# ['Semko LLC', 'ok']
# ['   20520001  TOMATO CHERRY FROZEN WHOLE20520001 ТОМАТ ЧЕРРИ ЗАМОРОЖЕННЫЙ ЦЕЛЫЙ', 'ok']
# ['30.04.2020', 'ok']
# ['DDU', 'ok']
# [' 30.04.2020', 'ok']
# ['carton', 'ok']
# [60, 'ok']
# [31.55, 'ok']
# ['1.893,00  UAH', 'ok']
# name is Veres, FOP
# []
# ['Veres, FOP', 'ok']
# ['   20020033  BLUEBERRY FROZEN CLASS 120020033 ЧЕРНИКА ЗАМОРОЖЕННАЯ КЛАСС 1', 'ok']
# ['24.04.2020', 'ok']
# ['DDU', 'ok']
# [' 24.04.2020', 'ok']
# ['paperbag', 'ok']
# [18825, 'ok']
# [78.23, 'ok']
# ['1.472.679,75  UAH', 'ok']
# name is Zemlia Organic LLC
# ['   20010118  STRAWBERRY FROZEN ORGANIC', '   20010118  STRAWBERRY FROZEN ORGANIC']
# ['Zemlia Organic LLC', 'ok']
# ['   20030033  RASPBERRY FROZEN WHOLE20030033 МАЛИНА ЦЕЛЬНАЯ ЗАМОРОЖЕННАЯ', 'ok']
# ['16.04.2020', 'ok']
# ['DDU', 'ok']
# [' 16.04.2020', 'ok']
# ['carton', 'ok']
# [2512, 'ok']
# [37.5, 'ok']
# ['94.200,00  UAH', 'ok']
# name is Zemlia Organic LLC
# ['   20010118  STRAWBERRY FROZEN ORGANIC', '   20010118  STRAWBERRY FROZEN ORGANIC', '   20030033  RASPBERRY FROZEN WHOLE']
# ['Zemlia Organic LLC', 'ok']
# ['   20030034  RASPBERRY FROZEN CRUMBS20030034 МАЛИНЫ ЗАМОРОЖЕННЫЕ КЫШКИ', 'ok']
# ['16.04.2020', 'ok']
# ['DDU', 'ok']
# [' 16.04.2020', 'ok']
# ['carton', 'ok']
# [907, 'ok']
# [37.5, 'ok']
# ['34.012,50  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE']
# ['Semko LLC', 'ok']
# ['   20200003  MANGO FROZEN CUT BITS20200003 ЗАМОРОЖЕННЫЕ БИТЫ ИЗ МАНГО', 'ok']
# ['24.03.2020', 'ok']
# ['DDU', 'ok']
# [' 24.03.2020', 'ok']
# ['carton', 'ok']
# [1260, 'ok']
# [60.9, 'ok']
# ['76.734,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS']
# ['Semko LLC', 'ok']
# ['   20320000  APRICOT FROZEN HALVES20320000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ АБРИКОСА', 'ok']
# ['24.03.2020', 'ok']
# ['DDU', 'ok']
# [' 24.03.2020', 'ok']
# ['carton', 'ok']
# [1500, 'ok']
# [25.05, 'ok']
# ['37.575,00  UAH', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES']
# ['Semko LLC', 'ok']
# ['   20240005  PINEAPPLE FROZEN PIECES20240005 ЗАМОРОЖЕННЫЕ ЧАСТИ АНАНАСА', 'ok']
# ['24.03.2020', 'ok']
# ['DDU', 'ok']
# [' 24.03.2020', 'ok']
# ['carton', 'ok']
# [20, 'ok']
# [71.2, 'ok']
# ['1.424,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES']
# ['Semko LLC', 'ok']
# ['   20200003  MANGO FROZEN CUT BITS20200003 ЗАМОРОЖЕННЫЕ БИТЫ ИЗ МАНГО', 'ok']
# ['20.03.2020', 'ok']
# ['DDU', 'ok']
# [' 20.03.2020', 'ok']
# ['carton', 'ok']
# [1160, 'ok']
# [62.95, 'ok']
# ['73.022,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS']
# ['Semko LLC', 'ok']
# ['   20520003  TOMATO FROZEN PIECES20520003 ЗАМОРОЖЕННЫЕ ЧАСТИ ТОМАТА', 'ok']
# ['18.03.2020', 'ok']
# ['DDU', 'ok']
# [' 18.03.2020', 'ok']
# ['carton', 'ok']
# [10, 'ok']
# [31.55, 'ok']
# ['315,50  UAH', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES']
# ['Semko LLC', 'ok']
# ['   20200003  MANGO FROZEN CUT BITS20200003 ЗАМОРОЖЕННЫЕ БИТЫ ИЗ МАНГО', 'ok']
# ['18.03.2020', 'ok']
# ['DDU', 'ok']
# [' 18.03.2020', 'ok']
# ['carton', 'ok']
# [400, 'ok']
# [56.5, 'ok']
# ['22.600,00  UAH', 'ok']
# name is Yarofrut LLC
# ['   20250003  CARROT FROZEN CUBE 10X10 MM']
# ['Yarofrut LLC', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE20050000 ИСТОЧНИКИ ЗАМОРОЖЕННЫЕ КЛАСС 1, БЕЗ КАМНЯ', 'ok']
# ['13.03.2020', 'ok']
# ['DDU', 'ok']
# [' 13.03.2020', 'ok']
# ['carton', 'ok']
# [9450, 'ok']
# [44.08, 'ok']
# ['416.556,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS']
# ['Semko LLC', 'ok']
# ['   20240005  PINEAPPLE FROZEN PIECES20240005 ЗАМОРОЖЕННЫЕ ЧАСТИ АНАНАСА', 'ok']
# ['12.03.2020', 'ok']
# ['DDU', 'ok']
# [' 12.03.2020', 'ok']
# ['carton', 'ok']
# [1500, 'ok']
# [61.45, 'ok']
# ['92.175,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES']
# ['Semko LLC', 'ok']
# ['   20320000  APRICOT FROZEN HALVES20320000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ АБРИКОСА', 'ok']
# ['12.03.2020', 'ok']
# ['DDU', 'ok']
# [' 12.03.2020', 'ok']
# ['carton', 'ok']
# [300, 'ok']
# [28.95, 'ok']
# ['8.685,00  UAH', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES']
# ['Semko LLC', 'ok']
# ['   20200003  MANGO FROZEN CUT BITS20200003 ЗАМОРОЖЕННЫЕ БИТЫ ИЗ МАНГО', 'ok']
# ['12.03.2020', 'ok']
# ['DDU', 'ok']
# [' 12.03.2020', 'ok']
# ['carton', 'ok']
# [400, 'ok']
# [58.85, 'ok']
# ['23.540,00  UAH', 'ok']
# name is Yarofrut LLC
# ['   20250003  CARROT FROZEN CUBE 10X10 MM', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE']
# ['Yarofrut LLC', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE20050000 ИСТОЧНИКИ ЗАМОРОЖЕННЫЕ КЛАСС 1, БЕЗ КАМНЯ', 'ok']
# ['20.02.2020', 'ok']
# ['DDU', 'ok']
# [' 20.02.2020', 'ok']
# ['carton', 'ok']
# [1260, 'ok']
# [41.67, 'ok']
# ['52.504,20  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS']
# ['Semko LLC', 'ok']
# ['   20200003  MANGO FROZEN CUT BITS20200003 ЗАМОРОЖЕННЫЕ БИТЫ ИЗ МАНГО', 'ok']
# ['18.02.2020', 'ok']
# ['DDU', 'ok']
# [' 18.02.2020', 'ok']
# ['carton', 'ok']
# [1400, 'ok']
# [54.75, 'ok']
# ['76.650,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS']
# ['Semko LLC', 'ok']
# ['   20260005  APPLE FROZEN CUBE WITHOUT SKIN20260005 ЯБЛОЧНЫЙ ЗАМОРОЖЕННЫЙ КУБ БЕЗ КОЖИ', 'ok']
# ['11.02.2020', 'ok']
# ['EXW', 'ok']
# [' 17.02.2020', 'ok']
# ['paperbag', 'ok']
# [25, 'ok']
# [25.65, 'ok']
# ['641,25  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20260005  APPLE FROZEN CUBE WITHOUT SKIN']
# ['Semko LLC', 'ok']
# ['   20110008  BLACK CURRANT FROZEN20110008 ЧЕРНАЯ СМОРОДИНА ЗАМОРОЖЕННАЯ', 'ok']
# ['07.02.2020', 'ok']
# ['DDU', 'ok']
# [' 07.02.2020', 'ok']
# ['paperbag', 'ok']
# [10000, 'ok']
# [27.5, 'ok']
# ['275.000,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20260005  APPLE FROZEN CUBE WITHOUT SKIN', '   20110008  BLACK CURRANT FROZEN']
# ['Semko LLC', 'ok']
# ['   20110008  BLACK CURRANT FROZEN20110008 ЧЕРНАЯ СМОРОДИНА ЗАМОРОЖЕННАЯ', 'ok']
# ['07.02.2020', 'ok']
# ['DDU', 'ok']
# [' 07.02.2020', 'ok']
# ['paperbag', 'ok']
# [10400, 'ok']
# [30.3, 'ok']
# ['315.120,00  UAH', 'ok']
# name is Tkach Oksana, FOP
# []
# ['Tkach Oksana, FOP', 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY20020023 BLUEBERRY FROZEN PRESS-КАЧЕСТВО', 'ok']
# ['07.02.2020', 'ok']
# ['DDU', 'ok']
# [' 07.02.2020', 'ok']
# ['paperbag', 'ok']
# [4271, 'ok']
# [61.36, 'ok']
# ['262.068,56  UAH', 'ok']
# name is Tkach Y M O FOP
# ['   20320000  APRICOT FROZEN HALVES', '   20090002  SEA BUCKTHORN FROZEN CLASS 2']
# ['Tkach Y M O FOP', 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY20020023 BLUEBERRY FROZEN PRESS-КАЧЕСТВО', 'ok']
# ['07.02.2020', 'ok']
# ['DDU', 'ok']
# [' 07.02.2020', 'ok']
# ['paperbag', 'ok']
# [9729, 'ok']
# [61.36, 'ok']
# ['596.971,44  UAH', 'ok']
# name is Tkach Y M O FOP
# ['   20320000  APRICOT FROZEN HALVES', '   20090002  SEA BUCKTHORN FROZEN CLASS 2', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY']
# ['Tkach Y M O FOP', 'ok']
# ['   20020003  BLUEBERRY FROZEN CLASS 220020003 ЧЕРНИКА ЗАМОРОЖЕННАЯ КЛАСС 2', 'ok']
# ['07.02.2020', 'ok']
# ['DDU', 'ok']
# [' 07.02.2020', 'ok']
# ['plast.box_sm', 'ok']
# [116, 'ok']
# [81.53, 'ok']
# ['9.457,48  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20260005  APPLE FROZEN CUBE WITHOUT SKIN', '   20110008  BLACK CURRANT FROZEN', '   20110008  BLACK CURRANT FROZEN']
# ['Semko LLC', 'ok']
# ['   20640000  PLUM FROZEN HALVES20640000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ СЛИВЫ', 'ok']
# ['30.01.2020', 'ok']
# ['DDU', 'ok']
# [' 24.01.2020', 'ok']
# ['carton', 'ok']
# [200, 'ok']
# [16.45, 'ok']
# ['3.290,00  UAH', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20260005  APPLE FROZEN CUBE WITHOUT SKIN', '   20110008  BLACK CURRANT FROZEN', '   20110008  BLACK CURRANT FROZEN', '   20640000  PLUM FROZEN HALVES']
# ['Semko LLC', 'ok']
# ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM20240007 АНАНАС ЗАМОРОЖЕННЫЙ КУБИК 20Х20 ММ', 'ok']
# ['30.01.2020', 'ok']
# ['DDU', 'ok']
# [' 24.01.2020', 'ok']
# ['carton', 'ok']
# [1200, 'ok']
# [61.45, 'ok']
# ['73.740,00  UAH', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20260005  APPLE FROZEN CUBE WITHOUT SKIN', '   20110008  BLACK CURRANT FROZEN', '   20110008  BLACK CURRANT FROZEN', '   20640000  PLUM FROZEN HALVES', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM']
# ['Semko LLC', 'ok']
# ['   20180004  KIWI FROZEN BITS20180004 ЗАМОРОЖЕННЫЕ БИТКИ КИВИ', 'ok']
# ['30.01.2020', 'ok']
# ['DDU', 'ok']
# [' 24.01.2020', 'ok']
# ['carton', 'ok']
# [700, 'ok']
# [58.95, 'ok']
# ['41.265,00  UAH', 'ok']
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20260005  APPLE FROZEN CUBE WITHOUT SKIN', '   20110008  BLACK CURRANT FROZEN', '   20110008  BLACK CURRANT FROZEN', '   20640000  PLUM FROZEN HALVES', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20180004  KIWI FROZEN BITS']
# ['Semko LLC', 'ok']
# ['   20290002  PEACH FROZEN CUBE 10X1020290002 ПЕРСИК ЗАМОРОЖЕННЫЙ КУБ 10X10', 'ok']
# ['30.01.2020', 'ok']
# ['DDU', 'ok']
# [' 24.01.2020', 'ok']
# ['carton', 'ok']
# [700, 'ok']
# [42.25, 'ok']
# ['29.575,00  UAH', 'ok']
# name is Semko LLC
# ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20260005  APPLE FROZEN CUBE WITHOUT SKIN', '   20110008  BLACK CURRANT FROZEN', '   20110008  BLACK CURRANT FROZEN', '   20640000  PLUM FROZEN HALVES', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20180004  KIWI FROZEN BITS', '   20290002  PEACH FROZEN CUBE 10X10']
# ['Semko LLC', 'ok']
# ['   20320000  APRICOT FROZEN HALVES20320000 ЗАМОРОЖЕННЫЕ ПОЛОВИНЫ АБРИКОСА', 'ok']
# ['30.01.2020', 'ok']
# ['DDU', 'ok']
# [' 30.01.2020', 'ok']
# ['carton', 'ok']
# [750, 'ok']
# [27.25, 'ok']
# ['20.437,50  UAH', 'ok']
# name is Tkach Oksana, FOP
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY']
# ['Tkach Oksana, FOP', 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY20020023 BLUEBERRY FROZEN PRESS-КАЧЕСТВО', 'ok']
# ['11.01.2020', 'ok']
# ['DDU', 'ok']
# [' 11.01.2020', 'ok']
# ['paperbag', 'ok']
# [19699, 'ok']
# [62.84, 'ok']
# ['1.237.885,16  UAH', 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY']
# ['Tkach Oksana, FOP', 'ok']
# ['NoneНикто', 'ok']
# ['11.01.2020', 'ok']
# ['DDU', 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY', 'None']
# ['Tkach Oksana, FOP', 'ok']
# ['NoneНикто', 'ok']
# ['11.01.2020', 'ok']
# ['DDU', 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY', 'None', 'None']
# ['Tkach Oksana, FOP', 'ok']
# ['NoneНикто', 'ok']
# ['11.01.2020', 'ok']
# ['DDU', 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY', 'None', 'None', 'None']
# ['Tkach Oksana, FOP', 'ok']
# ['NoneНикто', 'ok']
# ['11.01.2020', 'ok']
# ['DDU', 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY', 'None', 'None', 'None', 'None']
# ['Tkach Oksana, FOP', 'ok']
# ['NoneНикто', 'ok']
# ['11.01.2020', 'ok']
# ['DDU', 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY', 'None', 'None', 'None', 'None', 'None']
# ['Tkach Oksana, FOP', 'ok']
# ['NoneНикто', 'ok']
# ['11.01.2020', 'ok']
# ['DDU', 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']
# [None, 'ok']

# %%
write(1,1,'yes')
# Out:
# ['yes', 'ok']

# %%
for i in base.items():
    print(i)
# Out:
# ('Address / product/ Постачальник та продукт', [])
# ('Parfeniuk V. V.', ['   20020038  BLUEBERRY FROZEN'])
# ('Berry Mor LLC ', ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20640000  PLUM FROZEN HALVES', '   20640000  PLUM FROZEN HALVES', '   20630001  SPINACH FROZEN CUT', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20470000  PEAR FROZEN CUBE', '   20640000  PLUM FROZEN HALVES', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20010018  STRAWBERRY FROZEN', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20620000  GREEN PEAS FROZEN', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE'])
# ('Nagaychuk D V FOP', ['   20320000  APRICOT FROZEN HALVES'])
# ('Krasberi-Ukraina LLC', ['   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM', '   20200006  MANGO FROZEN CUBE 20 X 20 MM'])
# ('Hordiichuk A. V.', ['   20020038  BLUEBERRY FROZEN'])
# ('Danon Dnipro, LLC', ['   70010012  STRAWBERRY FROZEN CLASS 1 CUBE 10X10 MM'])
# ('Zemlia Organic LLC', ['   20010118  STRAWBERRY FROZEN ORGANIC', '   20010118  STRAWBERRY FROZEN ORGANIC', '   20030033  RASPBERRY FROZEN WHOLE', '   20030034  RASPBERRY FROZEN CRUMBS'])
# ('Semko LLC', ['   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20670000  CORN FROZEN CRUMBS', '   20630001  SPINACH FROZEN CUT', '   20320000  APRICOT FROZEN HALVES', '   20520001  TOMATO CHERRY FROZEN WHOLE', '   20200003  MANGO FROZEN CUT BITS', '   20320000  APRICOT FROZEN HALVES', '   20240005  PINEAPPLE FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20520003  TOMATO FROZEN PIECES', '   20200003  MANGO FROZEN CUT BITS', '   20240005  PINEAPPLE FROZEN PIECES', '   20320000  APRICOT FROZEN HALVES', '   20200003  MANGO FROZEN CUT BITS', '   20200003  MANGO FROZEN CUT BITS', '   20260005  APPLE FROZEN CUBE WITHOUT SKIN', '   20110008  BLACK CURRANT FROZEN', '   20110008  BLACK CURRANT FROZEN', '   20640000  PLUM FROZEN HALVES', '   20240007  PINEAPPLE FROZEN CUBE 20X20 MM', '   20180004  KIWI FROZEN BITS', '   20290002  PEACH FROZEN CUBE 10X10', '   20320000  APRICOT FROZEN HALVES'])
# ('Zaxarchuk V.V. FOP', ['   20060014  CHOKEBERRY FROZEN'])
# ('Yarofrut LLC', ['   20250003  CARROT FROZEN CUBE 10X10 MM', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE', '   20050000  SOURCHERRY FROZEN CLASS 1 WHOLE WITHOUT STONE'])
# ('Buzuluk R.S. FOP', ['   20060014  CHOKEBERRY FROZEN'])
# ("Koval'chuk A.A.", ['   20730007  BOG BLUEBERRY FROZEN'])
# ('Setton, LLC', ['   20070011  LINGONBERRY FROZEN'])
# ('Kebaluk O R FOP', ['   20030037  RASPBERRY FROZEN'])
# ('Larus LLC', ['   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B', '   20020036  BLUEBERRY FROZEN B'])
# ('Hayberry LLC', ['   20010018  STRAWBERRY FROZEN'])
# ('TERCET-WEST, JLLC', ['   20020036  BLUEBERRY FROZEN B'])
# ('People', ['   20290003  PEACH FROZEN HALFS', '   20290003  PEACH FROZEN HALFS', '   20630001  SPINACH FROZEN CUT'])
# ('Kuts A.V. FOP', ['   70320004  APRICOT FROZEN HALFS'])
# ('Berry-Trade, LLC', ['   20010018  STRAWBERRY FROZEN'])
# ('Cetera, LLC', ['   20250003  CARROT FROZEN CUBE 10X10 MM', '   70670002  CORN FROZEN CRUMBS'])
# ('Tkach Y M O FOP', ['   20320000  APRICOT FROZEN HALVES', '   20090002  SEA BUCKTHORN FROZEN CLASS 2', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY', '   20020003  BLUEBERRY FROZEN CLASS 2'])
# ('DVIPA LLC', ['   20010118  STRAWBERRY FROZEN ORGANIC'])
# ('Veres, FOP', ['   20020033  BLUEBERRY FROZEN CLASS 1'])
# ('Tkach Oksana, FOP', ['   20020023  BLUEBERRY FROZEN PRESS-QUALITY', '   20020023  BLUEBERRY FROZEN PRESS-QUALITY', 'None', 'None', 'None', 'None', 'None', 'None'])

# %%
# Out:
# ['2']

# %%
# Out:
# 78.516
